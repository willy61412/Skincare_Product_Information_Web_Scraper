www.obagi.com/products/tint-broad-spectrum-spf-50-cool', 'https://www.obagi.com/products/obagi-clinical-dark-spot-disruptor-discoloration-correcting-serum', 'https://www.obagi.com/products/kinetin-hydrating-eye-cream', 'https://www.obagi.com/products/tint-broad-spectrum-spf-50-warm', 'https://www.obagi.com/products/obagi-clinical-blue-brilliance-triple-acid-peel', 'https://www.obagi.com/products/obagi-clinical-retinol-0-5-retexturizing-cream-acne', 'https://www.obagi.com/products/obagi-clinical-kinetin-hydrating-cream-moisturizer', 'https://www.obagi.com/products/suzanobgi-md-intensive-daily-repair-moisturizer', 'https://www.obagi.com/products/obagi-c-fx-exfoliating-day-lotion', 'https://www.obagi.com/products/professional-c-microdermabrasion-polish-mask', 'https://www.obagi.com/products/obagi-nu-derm-fx-exfoliant-sensitive-skin', 'https://www.obagi.com/products/obagi-nu-derm-fx-aha-exfoliant', 'https://www.obagi.com/products/clenziderm-acne-therapeutic-lotion', 'https://www.obagi.com/products/obagi-clinical-vitamin-c-arbutin-brightening-serum', 'https://www.obagi.com/products/obagi-clinical-kinetin-rejuvenating-moisturizing-serum', 'https://www.obagi.com/products/obagi-nu-derm-fx-blend-fx-serum', 'https://www.obagi.com/products/obagi-c-fx-c-therapy-night-cream', 'https://www.obagi.com/products/obagi-nu-derm-fx-clear-fx-serum', 'https://www.obagi.com/products/obagi-nu-derm-fx-healthy-skin-protection-broad-spectrum-spf-35', 'https://www.obagi.com/products/obagi-c-fx-system-normal-to-oily', 'https://www.obagi.com/products/clenziderm-acne-daily-care-foaming-cleanser', 'https://www.obagi.com/products/obagi-lash-and-brow-serum-set', 'https://www.obagi.com/products/obagi-day-to-night-hydration-skincare-set', 'https://www.obagi.com/products/professional-c-retinol-1-0-set', 'https://www.obagi.com/products/back-to-basic-15-set', 'https://www.obagi.com/products/back-to-basic-20-set', 'https://www.obagi.com/products/rejuvenating-eye-gel-cream', 'https://www.obagi.com/products/obagi-c-fx-system-normal-to-dry']

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

def crawl_product_info(url):
    dom = requests.get(url).text
    soup = BeautifulSoup(dom, 'html.parser')

    # Get Product Title
    title_tag = soup.find('head').find('title')
    product_title = title_tag.text.strip()

    # Get Product Price
    price_span = soup.find('span', class_="pdp-details__subs-price-wrapper body3--bold")
    if price_span:
        price = price_span.text.strip()
    else:
        price = "No Price"

    # Get Product Ingredients
    ingredients = ''
    h6_tag = soup.find('h6', string='Full Ingredients')
    if h6_tag:
        p_tag = h6_tag.find_next('p')
        if p_tag:
            ingredients = p_tag.text.strip()
        else:
            ingredients = "No Ingredients"
    else:
        ingredients = "No Ingredients"

    # Get Best for
    best_for_str = ''
    treat_div = soup.find('div', class_="pdp-details__skin_concerns pdp-details__skin-block")
    if treat_div:
        a_tags = treat_div.find_all('a')
        if a_tags:
            best_for_str = ', '.join([a_tag.text.strip() for a_tag in a_tags])
        else:
            best_for_str = "No Best for"
    else:
        best_for_str = "No Best for"

    # Get Skin Types
    skin_types_str = ''
    type_div = soup.find('div', class_="pdp-details__skin_types pdp-details__skin-block")
    if type_div:
        a_tags = type_div.find_all('a')
        if a_tags:
            skin_types_str = ', '.join([a_tag.text.strip() for a_tag in a_tags])
        else:
            skin_types_str = "No Skin Type"
    else:
        skin_types_str = "No Skin Type"

   # Get Before and After Image URLs
    image_urls_str = ''
    image_divs = soup.find_all('div', class_='comparison__slide-image')
    if image_divs:
        image_urls_str = ', '.join([div.find('img')['src'] for div in image_divs])
    else:
        image_urls_str = "No Images"

    return {
        'Product Title': product_title,
        'Product Price': price,
        'Product Ingredients': ingredients,
        'Best for': best_for_str,
        'Skin Types': skin_types_str,
        'Before and After Image URLs': image_urls_str
    }

def main():

    data = []
    for url in all_urls:
        product_info = crawl_product_info(url)
        data.append(product_info)

    df = pd.DataFrame(data)
    return df

if __name__ == '__main__':
    df = main()

# %%
print(df)
# Out:
#                                         Product Title Product Price  \
# 0       Skin Barrier Recovery Cream | Obagi Rebalance       $110.00
# 1           Hydrating Face Cream | Obagi Hydrate Luxe        $78.00
# 2   Hydrating Face Serum | Obagi Daily Hydro-Drops...       $105.00
# 3   Face Moisturizer | Obagi Hydrate Facial Moistu...        $58.00
# 4      Acne Therapeutic Hydrating Moisturizer | Obagi        $48.00
# ..                                                ...           ...
# 68      Vitamin C Serum 15% + Retinol 1.0 Set | Obagi      No Price
# 69             Back to Basics Set (Serum 15%) | Obagi      No Price
# 70             Back to Basics Set (Serum 20%) | Obagi      No Price
# 71  Hydrating Eye Gel | Obagi Rejuvenating Eye Gel...      No Price
# 72  Skin Brightening System: Normal to Dry Skin | ...      No Price
#
#                                   Product Ingredients  \
# 0   Aqua/water/eau, caprylic/capric triglyceride, ...
# ...

# %%
# Data Cleaning
df2 = df.copy()

# Data Cleaning
df2['Product Title'] = df2['Product Title'].apply(lambda x: x.split('|')[0].strip())
df2['Product Price'] = df2['Product Price'].str.replace('$', '')
df2['Before Image'] = df2['Before and After Image URLs'].apply(lambda x: x.split(',')[0].strip() if ',' in x else ('No Images' if x == 'No Images' else x.strip()))
df2['After Image'] = df2['Before and After Image URLs'].apply(lambda x: x.split(',')[1].strip() if (',' in x) and (len(x.split(',')) > 1) else ('No Images' if x == 'No Images' else ''))
df2['Product URLs'] = all_urls
df2.drop(columns=['Before and After Image URLs'], inplace=True)

print(df2)
# Out:
#                                   Product Title Product Price  \
# 0                   Skin Barrier Recovery Cream        110.00
# 1                          Hydrating Face Cream         78.00
# 2                          Hydrating Face Serum        105.00
# 3                              Face Moisturizer         58.00
# 4        Acne Therapeutic Hydrating Moisturizer         48.00
# ..                                          ...           ...
# 68        Vitamin C Serum 15% + Retinol 1.0 Set      No Price
# 69               Back to Basics Set (Serum 15%)      No Price
# 70               Back to Basics Set (Serum 20%)      No Price
# 71                            Hydrating Eye Gel      No Price
# 72  Skin Brightening System: Normal to Dry Skin      No Price
#
#                                   Product Ingredients  \
# 0   Aqua/water/eau, caprylic/capric triglyceride, ...
# 1   Aqua/water/eau, glycerin, caprylic/capric trig...
# 2   Aqua/water/eau, propanediol, glycerin, isonony...
# ...

# %%
# Download Excel file
from google.colab import files
df2.to_excel('Obagi_products.xlsx', index=False)
files.download('Obagi_products.xlsx')

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

def crawl_product_info(url):
    dom = requests.get(url).text
    soup = BeautifulSoup(dom, 'html.parser')

    # Get Product Title
    title_tag = soup.find('head').find('title')
    product_title = title_tag.text.strip()

    # Get Product Key Ingredients
    div_tag = soup.find('div', {'data-show-more-body': True})
    if div_tag:
        key_ingredients = ""
        h6_tags = div_tag.find_all('h6')
        for h6_tag in h6_tags:
            key_ingredients += h6_tag.text.strip() + ", "
        li_tags = div_tag.find_all('li')
        for li_tag in li_tags:
            key_ingredients += li_tag.text.strip() + ", "
        if key_ingredients:
            key_ingredients = key_ingredients[:-2]
        else:
            key_ingredients = "No Product Key Ingredients."
    else:
         key_ingredients = "No Product Key Ingredients."


    return {
        'Product Title': product_title,
        'Product Key Ingredients': key_ingredients
    }

def main():

    data = []
    for url in all_urls:
        product_info = crawl_product_info(url)
        data.append(product_info)

    df3 = pd.DataFrame(data)
    return df3

if __name__ == '__main__':
    df3 = main()

# %%
print(df3)
# Download Excel file
from google.colab import files
df3.to_excel('Obagi_products_key_ingredients.xlsx', index=False)
files.download('Obagi_products_key_ingredients.xlsx')
# Out:
#                                         Product Title  \
# 0       Skin Barrier Recovery Cream | Obagi Rebalance
# 1           Hydrating Face Cream | Obagi Hydrate Luxe
# 2   Hydrating Face Serum | Obagi Daily Hydro-Drops...
# 3   Face Moisturizer | Obagi Hydrate Facial Moistu...
# 4      Acne Therapeutic Hydrating Moisturizer | Obagi
# ..                                                ...
# 68      Vitamin C Serum 15% + Retinol 1.0 Set | Obagi
# 69             Back to Basics Set (Serum 15%) | Obagi
# 70             Back to Basics Set (Serum 20%) | Obagi
# 71  Hydrating Eye Gel | Obagi Rejuvenating Eye Gel...
# 72  Skin Brightening System: Normal to Dry Skin | ...
#
#                               Product Key Ingredients
# 0   BarrierPlex™ Technology, Full Ingredients, Pos...
# 1                 Tara Seed Extract, Full Ingredients
# 2   Niacinamide, Hibiscus Oil and Abyssinian Oil, ...
# 3                 Tara Seed Extract, Full Ingredients
# ...

# %%
# Data Cleaning
df4 = df3.copy()
df4['Product Key Ingredients'] = df4['Product Key Ingredients'].str.replace(', Full Ingredients', '')
df4['Product Key Ingredients'] = df4['Product Key Ingredients'].str.replace('.', '')
print(df4)
# Out:
#                                         Product Title  \
# 0       Skin Barrier Recovery Cream | Obagi Rebalance
# 1           Hydrating Face Cream | Obagi Hydrate Luxe
# 2   Hydrating Face Serum | Obagi Daily Hydro-Drops...
# 3   Face Moisturizer | Obagi Hydrate Facial Moistu...
# 4      Acne Therapeutic Hydrating Moisturizer | Obagi
# ..                                                ...
# 68      Vitamin C Serum 15% + Retinol 1.0 Set | Obagi
# 69             Back to Basics Set (Serum 15%) | Obagi
# 70             Back to Basics Set (Serum 20%) | Obagi
# 71  Hydrating Eye Gel | Obagi Rejuvenating Eye Gel...
# 72  Skin Brightening System: Normal to Dry Skin | ...
#
#                               Product Key Ingredients
# 0   BarrierPlex™ Technology, Postbiotics, Green Al...
# 1                                   Tara Seed Extract
# 2        Niacinamide, Hibiscus Oil and Abyssinian Oil
# 3                                   Tara Seed Extract
# ...

# %%
# Download Excel file
from google.colab import files
df4.to_excel('Obagi_products_key_ingredients.xlsx', index=False)
files.download('Obagi_products_key_ingredients.xlsx')
